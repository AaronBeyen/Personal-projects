# %%
import sympy as sp
import numpy as np
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from scipy.integrate import odeint

from IPython.display import display
sp.init_printing()
# %matplotlib notebook

# %%
g = 9.81
l = 1
k = 1
m = 1

# P = [x, x', theta, theta'] met ' = afgeleide en P[0] = x

def dP_dt(P, t):
    return [P[1], (l+P[0])*P[3]**2-k/m *P[0]+g*np.cos(P[2]),  P[3], -g/(l+P[0])*np.sin(P[2]) -2*P[1]/(l+P[0])*P[3]] # in de vergelijking dy/dt = f(y,t) is dit f(y,t)

# %%
ts =  np.linspace(0, 10, 500)


x0 = 10
v0 = 0
theta_0 = np.pi/2
omega_0 = 0

P0 = [x0, v0, theta_0, omega_0]
Ps = odeint(dP_dt, P0, ts)
y0 = Ps[:,0] # x(t)
y1 = Ps[:,1] # v(t) = d x/dt
y2 = Ps[:,2] # theta(t)
y3 = Ps[:,3] # omega(t)

# %%
# plotten x(t). Dit is nodig voor te weten hoe ver we onze r-as zullen moeten nemen in de polar plot

# %%
fig, ax = plt.subplots(1,1)
ax.set_xlim([0, 10])
ax.set_ylim([-20, 50])

# Vul hieronder de code aan.
X = ts
Y = y0
Z = y1
functie, = ax.plot([], [])
functie2, = ax.plot([], [])
dot, = ax.plot([], [], 'o', color='red')
dot2, = ax.plot([], [], 'o', color='green')

def animate(i):
    functie.set_data(X[:i], Y[:i])
    dot.set_data(X[i],Y[i])
plt.grid(True)

anim = animation.FuncAnimation(fig, animate, frames=len(X), interval=10)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.3939332346104">

# %%
# baan pendulum

# %%
fig = plt.figure(figsize=(6,6))
ax = plt.subplot(111, polar=True)
ax.set_theta_offset(3*np.pi/2)

ax.set_xlim([-3.1415, np.pi])
ax.set_ylim([0, 50])

# Vul hieronder de code aan.
X = y2
Y = y0
functie, = ax.plot([], [])
dot, = ax.plot([], [], 'o', color='red')
lijn, = ax.plot([],[], 'green')


def animate(i):
    functie.set_data(X[:i], Y[:i])
    dot.set_data(X[i],Y[i])
    #lijn.set_data([0, X[i]],[0,l])

anim = animation.FuncAnimation(fig, animate, frames=len(X), interval=50)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999942201557">

# %%
# stokje pendulum

# %%
fig = plt.figure(figsize=(6,6))
ax = plt.subplot(111, polar=True)
ax.set_theta_offset(3*np.pi/2)

ax.set_xlim([-3.1415, np.pi])
ax.set_ylim([0, 30])

# Vul hieronder de code aan.
X = y2
Y = y0
functie, = ax.plot([], [])
dot, = ax.plot([], [], 'o', color='red')
lijn, = ax.plot([],[], 'green')


def animate(i):
    dot.set_data(X[i],Y[i])
    lijn.set_data([0, X[i]],[0,Y[i]])

anim = animation.FuncAnimation(fig, animate, frames=len(X), interval=50)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999942201557">
