# %%
print(randrange(11))
# Out:
# 5

# %%
import sympy as sp
import numpy as np
import time
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from scipy.integrate import odeint
from random import randrange

from IPython.display import display, clear_output
sp.init_printing()
# %matplotlib notebook

# %%
fig, ax = plt.subplots(1,1)
ax.set_xlim([0, 10])
ax.set_ylim([0, 10])

amount = 1
l = []
for i in range(amount):
    dot, = ax.plot([], [], 'o', color='blue')
    l.append(dot)
x0 = 5
y0 = 5
l[0].set_data(x0,y0)



a = True

fruit, = ax.plot([], [], 'o', color='red')

fruitx = randrange(10)
fruity = randrange(10)
fruit_c = 0

fruit.set_data(fruitx,fruity)

while a is True:
    while fruit_c < 10:
        value = input("Please enter a string: ")

        if value == 'z':
            y0 = y0+1
        elif value == 's':
            y0 = y0-1
        elif value == 'd':
            x0 = x0+1
        elif value == 'q':
            x0 = x0-1
        elif value == 'stop':
            endloop
        else:
            print('Error, try again next time')
            
        if (x0 == fruitx) and (y0 == fruity):
            amount += 1
            for i in range(amount):
                dot, = ax.plot([], [], 'o', color='blue')
                l.append(dot)
            
            break
        
        for i in range(amount):
            l[i].set_data(x0,y0-i)
        fruit.set_data(fruitx,fruity)


        fig.canvas.draw()
        fig.canvas.flush_events()
        time.sleep(1)
        
        fruit_c += 1
    fruitx = randrange(11)
    fruity = randrange(11)
    fruit_c = 0


# Display
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Please enter a string: s
# Please enter a string: s
# Please enter a string: s
# Please enter a string: s
# Please enter a string: s
# Please enter a string:
# Error, try again next time
# Please enter a string: d
# Please enter a string: d
# Please enter a string: d
# Please enter a string: z
# Please enter a string: d
# Please enter a string: z
# Please enter a string: z
# Please enter a string: z
# Please enter a string: q
# Please enter a string: q
# Please enter a string: z
# Please enter a string: z
# Please enter a string: z
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-77e5a141e6dc> in <module>
#      26 while a is True:
#      27     while fruit_c < 10:
# ---> 28         value = input("Please enter a string: ")
#      29
#      30         if value == 'z':
#
# ...
